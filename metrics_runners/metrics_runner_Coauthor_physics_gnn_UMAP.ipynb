# %%
from metrics import *
import torch
from torch_geometric.datasets import Coauthor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
import random
import matplotlib.pyplot as plt
import numpy as np
from time import time
from tqdm import tqdm
from utils import *
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import umap
import trimap
from umap import UMAP
import warnings

random_state = 0
random.seed(0)
torch.manual_seed(0)

warnings.filterwarnings('ignore', message="n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.")
warnings.filterwarnings('ignore', message="Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.")
warnings.filterwarnings('ignore', message="Graph is not fully connected, spectral embedding may not work as expected.")

print("Cuda available?", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Cuda available? True

# %%
dataset_name = "Coauthor"
original_gnn = "GNN"
algorithm_name = "UMAP"


dataset = Coauthor(root='.', name="Physics")
data = dataset[0].to(device)
generate_train_test(data)


X = dataset[0].x.cpu().detach().numpy()
y = dataset[0].y.cpu().numpy()

# %%
# model = GCN(input_dim=dataset.num_node_features, hidden_dim=64, output_dim=16).to(device)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# train_loop(200, model, optimizer, data)

# # Extract features with the trained GNN
# model.eval()
# with torch.no_grad():
#     gnn_output = model(data)

# # Move the features to CPU for t-SNE
# gnn_output = gnn_output.cpu().numpy()

# %%
local_metrics = LocalMetric()

for metric in ['euclidean', 'manhattan', 'cosine']:
    # umap_post = UMAP(n_components=2, random_state=0, metric=metric)
    # umap_results = umap_post.fit_transform(gnn_output)

    # df_umap = pd.DataFrame(umap_results, columns=[f'{algorithm_name}1', f'{algorithm_name}2'])
    # df_umap['label'] = y
    # df_umap.to_csv(f'{dataset_name}_metric_{metric}_{algorithm_name}.csv', index=False)

    df = pd.read_csv(f'{dataset_name}_{original_gnn}_metric_{metric}_{algorithm_name}.csv')
    X_reduced = df[[f'{algorithm_name}1', f'{algorithm_name}2']].values
    labels = df['label'].values

    local_metrics.calculate_knn_gain_and_dr_quality(
        X_lds=X_reduced,
        X_hds=X,
        labels=labels,
        method_name="{} {}".format(f"{dataset_name}", f"{algorithm_name}-{metric}"),
    )

local_metrics.visualize(f"{dataset_name}-{original_gnn} {algorithm_name} metric")
# Out:
# Calculating d_hd
# Coauthor UMAP-euclidean
# Calculating d_hd
# Coauthor UMAP-manhattan
# Calculating d_hd
# Coauthor UMAP-cosine
# Finished.

# %%
local_metrics = LocalMetric()

for min_dist in [0.1, 0.25, 0.5, 0.99]:
    
    # umap_post = UMAP(n_components=2, random_state=0, min_dist=min_dist)
    # umap_results = umap_post.fit_transform(gnn_output)

    # df_umap = pd.DataFrame(umap_results, columns=[f'{algorithm_name}1', f'{algorithm_name}2'])
    # df_umap['label'] = y
    # df_umap.to_csv(f'{dataset_name}_min_dist_{min_dist}_{algorithm_name}.csv', index=False)

    df = pd.read_csv(f'{dataset_name}_{original_gnn}_min_dist_{min_dist}_{algorithm_name}.csv')
    X_reduced = df[[f'{algorithm_name}1', f'{algorithm_name}2']].values
    labels = df['label'].values

    local_metrics.calculate_knn_gain_and_dr_quality(
        X_lds=X_reduced,
        X_hds=X,
        labels=labels,
        method_name="{} {}".format(dataset_name, f"{algorithm_name}-{min_dist}"),
    )

local_metrics.visualize(f"{dataset_name}-{original_gnn} {algorithm_name} min_dist")
# Out:
# Calculating d_hd
# Coauthor UMAP-0.1
# Calculating d_hd
# Coauthor UMAP-0.25
# Calculating d_hd
# Coauthor UMAP-0.5
# Calculating d_hd
# Coauthor UMAP-0.99
# Finished.

# %%
local_metrics = LocalMetric()

for n_neighbors in [10, 20, 30]:

    # umap_post = UMAP(n_components=2, random_state=0, n_neighbors=n_neighbors)
    # umap_results = umap_post.fit_transform(gnn_output)

    # df_umap = pd.DataFrame(umap_results, columns=[f'{algorithm_name}1', f'{algorithm_name}2'])
    # df_umap['label'] = y
    # df_umap.to_csv(f'{dataset_name}_n_neighbors_{n_neighbors}_{algorithm_name}.csv', index=False)

    df = pd.read_csv(f'{dataset_name}_{original_gnn}_n_neighbors_{n_neighbors}_{algorithm_name}.csv')
    X_reduced = df[[f'{algorithm_name}1', f'{algorithm_name}2']].values
    labels = df['label'].values
    
    local_metrics.calculate_knn_gain_and_dr_quality(
        X_lds=X_reduced,
        X_hds=X,
        labels=labels,
        method_name="{} {}".format(dataset_name, f"{algorithm_name}-{n_neighbors}"),
    )

local_metrics.visualize(f"{dataset_name}-{original_gnn} {algorithm_name} n_neighbors")
# Out:
# Calculating d_hd
# Coauthor UMAP-10
# Calculating d_hd
# Coauthor UMAP-20
# Calculating d_hd
# Coauthor UMAP-30
# Finished.
