# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.manifold import TSNE
import umap
import trimap
import pacmap
from sklearn.datasets import fetch_openml

# Load MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist.data, mnist.target.astype(int)

# Reduce to 2 dimensions using tSNE, UMAP, TRIMAP, and PACMAP
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200)
X_tsne = tsne.fit_transform(X)

umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1)
X_umap = umap_model.fit_transform(X)

trimap_model = trimap.TRIMAP(n_inliers=10, n_outliers=5)
X_trimap = trimap_model.fit_transform(X)

pacmap_model = pacmap.PaCMAP(n_neighbors=15)
X_pacmap = pacmap_model.fit_transform(X)

# Plotting the results
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# tSNE plot
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette='tab10', ax=axs[0, 0], legend=None)
axs[0, 0].set_title('tSNE')

# UMAP plot
sns.scatterplot(x=X_umap[:, 0], y=X_umap[:, 1], hue=y, palette='tab10', ax=axs[0, 1], legend=None)
axs[0, 1].set_title('UMAP')

# TRIMAP plot
sns.scatterplot(x=X_trimap[:, 0], y=X_trimap[:, 1], hue=y, palette='tab10', ax=axs[1, 0], legend=None)
axs[1, 0].set_title('TRIMAP')

# PACMAP plot
sns.scatterplot(x=X_pacmap[:, 0], y=X_pacmap[:, 1], hue=y, palette='tab10', ax=axs[1, 1], legend=None)
axs[1, 1].set_title('PACMAP')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
color_dict = {0: '#1f77b4', 1: '#ff7f0e', 2: '#2ca02c', 3: '#d62728', 4: '#9467bd', 5: '#8c564b', 6: '#e377c2', 7: '#7f7f7f', 8: '#bcbd22', 9: '#17becf'}
colors = [color_dict[i] for i in y]

# Plotting the results
fig, axs = plt.subplots(1, 4, figsize=(20, 5))

# tSNE plot
axs[0].scatter(X_tsne[:, 0], X_tsne[:, 1], c=colors, s=2)
axs[0].set_title('tSNE')
axs[0].set_xticks([])
axs[0].set_yticks([])

# UMAP plot
axs[1].scatter(X_umap[:, 0], X_umap[:, 1], c=colors, s=2)
axs[1].set_title('UMAP')
axs[1].set_xticks([])
axs[1].set_yticks([])

# TRIMAP plot
axs[2].scatter(X_trimap[:, 0], X_trimap[:, 1], c=colors, s=2)
axs[2].set_title('TRIMAP')
axs[2].set_xticks([])
axs[2].set_yticks([])

# PACMAP plot
axs[3].scatter(X_pacmap[:, 0], X_pacmap[:, 1], c=colors, s=2)
axs[3].set_title('PACMAP')
axs[3].set_xticks([])
axs[3].set_yticks([])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.manifold import TSNE
import umap
import trimap
import pacmap
from sklearn.datasets import fetch_openml


# Load FMNIST dataset
fmnist = fetch_openml('Fashion-MNIST', version=1)
X, y = fmnist.data, fmnist.target.astype(int)

# Reduce to 2 dimensions using tSNE, UMAP, TRIMAP, and PACMAP
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200)
X_tsne = tsne.fit_transform(X)

umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1)
X_umap = umap_model.fit_transform(X)

trimap_model = trimap.TRIMAP(n_inliers=10, n_outliers=5)
X_trimap = trimap_model.fit_transform(X)

pacmap_model = pacmap.PaCMAP(n_neighbors=15)
X_pacmap = pacmap_model.fit_transform(X)

# Define color dictionary
color_dict = {0: '#1f77b4', 1: '#ff7f0e', 2: '#2ca02c', 3: '#d62728', 4: '#9467bd', 5: '#8c564b', 6: '#e377c2', 7: '#7f7f7f', 8: '#bcbd22', 9: '#17becf'}
colors = [color_dict[i] for i in y]

# Plotting the results
fig, axs = plt.subplots(1, 4, figsize=(20, 5))

# tSNE plot
axs[0].scatter(X_tsne[:, 0], X_tsne[:, 1], c=colors, s=2)
axs[0].set_title('tSNE')
axs[0].set_xticks([])
axs[0].set_yticks([])

# UMAP plot
axs[1].scatter(X_umap[:, 0], X_umap[:, 1], c=colors, s=2)
axs[1].set_title('UMAP')
axs[1].set_xticks([])
axs[1].set_yticks([])

# TRIMAP plot
axs[2].scatter(X_trimap[:, 0], X_trimap[:, 1], c=colors, s=2)
axs[2].set_title('TRIMAP')
axs[2].set_xticks([])
axs[2].set_yticks([])

# PACMAP plot
axs[3].scatter(X_pacmap[:, 0], X_pacmap[:, 1], c=colors, s=2)
axs[3].set_title('PACMAP')
axs[3].set_xticks([])
axs[3].set_yticks([])

# Adjust layout
plt.tight_layout()
plt.show()
